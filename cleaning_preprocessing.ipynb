# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

# %%
city_to_la_metro_county = {
    'FAIRMONT': 'Los Angeles',
    'BLYTHE': 'Riverside',
    'RIVERSIDE': 'Riverside',
    'ROLLING HILLS': 'Los Angeles',
    'BERRY CREEK': 'Butte',
    'OROVILLE': 'Butte',
    'LOS ANGELES': 'Los Angeles',
    'BLACK BUTTE': 'Butte',
    'LONG BEACH': 'Los Angeles',
    'PALM DESERT': 'Riverside',
    'RANCHO MIRAGE': 'Riverside',
    'RANCHO PALOS VERDES': 'Los Angeles',
    'ROLLING HILLS ESTATES': 'Los Angeles',
    'CARSON': 'Los Angeles',
    'MANHATTAN BEACH': 'Los Angeles',
    'CHICO': 'Butte',
    'LAKE ELSINORE': 'Riverside',
    'LA CANADA FLINTRIDGE': 'Los Angeles',
    'POMONA': 'Los Angeles',
    'BRADBURY': 'Los Angeles',
    'AVALON': 'Los Angeles',
    'PALOS VERDES ESTATES': 'Los Angeles',
    'SOUTH EL MONTE': 'Los Angeles',
    'PALM SPRINGS': 'Riverside',
    'DESERT CENTER': 'Riverside',
    'WESTLAKE VILLAGE': 'Los Angeles',
    'ALTADENA': 'Los Angeles',
    'ALHAMBRA': 'Los Angeles',
    'ARCADIA': 'Los Angeles',
    'FEATHER FALLS': 'Butte',
    'GLENDALE': 'Los Angeles',
    'CORONA': 'Riverside',
    'PERRIS': 'Riverside',
    'MONROVIA': 'Los Angeles',
    'CITY OF INDUSTRY': 'Los Angeles',
    'CHATSWORTH': 'Los Angeles',
    'PASADENA': 'Los Angeles',
    'TEMPLE CITY': 'Los Angeles',
    'PALOS VERDES EST': 'Los Angeles',
    'GARDENA': 'Los Angeles',
    'MONTEBELLO': 'Los Angeles',
    'PLS VRDS EST': 'Los Angeles',
    'HERMOSA BEACH': 'Los Angeles',
    'LA CRESCENTA': 'Los Angeles',
    'CLAREMONT': 'Los Angeles',
    'BURBANK': 'Los Angeles',
    'REDONDO BEACH': 'Los Angeles',
    'INGLEWOOD': 'Los Angeles',
    'SANTA MONICA': 'Los Angeles',
    'LA QUINTA': 'Riverside',
    'TEMECULA': 'Riverside',
    'ROLLING HLS': 'Los Angeles',
    'ACTON': 'Los Angeles',
    'AZUSA': 'Los Angeles',
    'BEAUMONT': 'Riverside',
    'SAN MARINO': 'Los Angeles',
    'SIERRA MADRE': 'Los Angeles',
    'COMPTON': 'Los Angeles',
    'MT BALDY': 'San Bernardino',
    'BANGOR': 'Butte',
    'CONCOW': 'Butte',
    'WEST COVINA': 'Los Angeles',
    'LOS ARBOLES, CHICO': 'Butte',
    'MONTEREY PARK': 'Los Angeles',
    'SAN GABRIEL': 'Los Angeles',
    'CULVER CITY': 'Los Angeles',
    'CALIMESA': 'Riverside',
    'LANCASTER': 'Los Angeles',
    'SAN DIMAS': 'Los Angeles',
    'SAN JACINTO': 'Riverside',
    'LA HABRA HEIGHTS': 'Los Angeles',
    'MALIBU': 'Los Angeles',
    'LA PUENTE': 'Los Angeles',
    'WALNUT': 'Los Angeles',
    'HEMET': 'Riverside',
    'SOUTH PASADENA': 'Los Angeles',
    'DUARTE': 'Los Angeles',
    'COVINA': 'Los Angeles',
    'BEVERLY HILLS': 'Los Angeles',
    'GLENDORA': 'Los Angeles',
    'CITY INDUSTRY': 'Los Angeles',
    'SAN FERNANDO': 'Los Angeles',
    'DIAMOND BAR': 'Los Angeles',
    'EL SEGUNDO': 'Los Angeles',
    'NORCO': 'Riverside',
    'TOPANGA': 'Los Angeles',
    'PARADISE': 'Butte',
    'ANTELOPE ACRES': 'Los Angeles',
    'DOWNEY': 'Los Angeles',
    'VENICE': 'Los Angeles',
    'TORRANCE': 'Los Angeles',
    'BANNING': 'Riverside',
    'LA VERNE': 'Los Angeles',
    'PALMDALE': 'Los Angeles',
    'SIGNAL HILL': 'Los Angeles',
    'WHITTIER': 'Los Angeles',
    'COMMERCE': 'Los Angeles',
    'SOUTH SAN GABRIEL': 'Los Angeles',
    'WEST HOLLYWOOD': 'Los Angeles',
    'WILMINGTON': 'Los Angeles',
    'LOMITA': 'Los Angeles',
    'CITY OF COMMERCE': 'Los Angeles',
    'ROSEMEAD': 'Los Angeles',
    'SAN PEDRO': 'Los Angeles',
    'PACOIMA': 'Los Angeles',
    'SOUTH GATE': 'Los Angeles',
    'EL MONTE': 'Los Angeles',
    'MORENO VALLEY': 'Riverside',
    'BELLFLOWER': 'Los Angeles',
    'LYNWOOD': 'Los Angeles',
    'TOLUCA LAKE': 'Los Angeles',
    'MECCA': 'Riverside',
    'SANTA FE SPRINGS': 'Los Angeles',
    'LITTLEROCK': 'Los Angeles',
    'SUN VILLAGE': 'Los Angeles',
    'LEONA VALLEY': 'Los Angeles',
    'AGUA DULCE': 'Los Angeles',
    'INDUSTRY': 'Los Angeles',
    'THERMAL': 'Riverside',
    'BALDWIN PARK': 'Los Angeles',
    'HACIENDA HEIGHTS': 'Los Angeles',
    'TUJUNGA': 'Los Angeles',
    'SANTA FE SPGS': 'Los Angeles',
    'MISSION HILLS': 'Los Angeles',
    'SAUGUS': 'Los Angeles',
    'PICO RIVERA': 'Los Angeles',
    'LITTEROCK': 'Los Angeles',
    'LENNOX': 'Los Angeles',
    'HARBOR CITY': 'Los Angeles',
    'IRWINDALE': 'Los Angeles',
    'VALINDA': 'Los Angeles',
    'COHASSET': 'Butte',
    'SUN VALLEY': 'Los Angeles',
    'DESERT HOT SPRINGS': 'Riverside',
    'SHADOW HILLS': 'Los Angeles',
    'NORTH SHORE': 'Riverside',
    'NORTHRIDGE': 'Los Angeles',
    'SANTA CLARITA': 'Los Angeles',
    'NORTH HILLS': 'Los Angeles',
    'LITTLE ROCK': 'Los Angeles',
    'MARINA DEL REY': 'Los Angeles',
    'PLAYA DEL REY': 'Los Angeles',
    'HOLLYWOOD': 'Los Angeles',
    'GRIDLEY': 'Butte',
    'SUNLAND': 'Los Angeles',
    'DURHAM': 'Butte',
    'ARLETA': 'Los Angeles',
    'COACHELLA': 'Riverside',
    'CALABASAS': 'Los Angeles',
    'EAST LOS ANGELES': 'Los Angeles',
    'JUNIPER HILLS': 'Los Angeles',
    'NORTH HOLLYWOOD': 'Los Angeles',
    'BELLFLOWER,': 'Los Angeles',
    'LA HABRA': 'Orange',
    'LAKE VIEW TERRACE': 'Los Angeles',
    'GRANADA HILLS': 'Los Angeles',
    'LA CANAD-FLT': 'Los Angeles',
    'ARCADI': 'Los Angeles',
    'POMON': 'Los Angeles',
    'CHERRY VALLEY': 'Riverside',
    'MURRIETA': 'Riverside',
    'SO PASADENA': 'Los Angeles',
    'SIMI VALLEY': 'Ventura',
    'STUDIO CITY': 'Los Angeles',
    'SOUTH GRAND GABRIEL': 'Los Angeles',
    'PACIFIC PALISADES': 'Los Angeles',
    'TOLUCA TERRACE': 'Los Angeles',
    'SUN VALLEY CALIF': 'Los Angeles',
    'PLAYA VIST': 'Los Angeles',
    'NORWALK': 'Los Angeles',
    'SYLMAR': 'Los Angeles',
    'SOUTH WHITTIER': 'Los Angeles',
    'NORWALK,': 'Los Angeles',
    'BEL AIR': 'Los Angeles',
    'PEARBLOSSOM': 'Los Angeles',
    'HARBOR CIT': 'Los Angeles',
    'NEWHALL': 'Los Angeles',
    'PALERMO': 'Butte',
    'CERRITOS': 'Los Angeles',
    'TORRANC': 'Los Angeles',
    'VAN NUYS': 'Los Angeles',
    'DOWNEY,': 'Los Angeles',
    'MONTE NIDO': 'Los Angeles',
    'DOWNEY CA 90241': 'Los Angeles',
    'CANYON COUNTRY': 'Los Angeles',
    'DAYS CREEK': 'Riverside',
    'RANCHOS VERDES': 'Los Angeles',
    'BOWERS GUILDS': 'Los Angeles',
    'JURUPA VALLEY': 'Riverside',
    'HONCUT': 'Butte',
    'PEARLBLOSSOM': 'Los Angeles',
    'FORBESTOWN': 'Butte',
    'ROWLAND HEIGHTS': 'Los Angeles',
    'SAN FERNANDO VALLEY': 'Los Angeles',
    'KAGEL CANYON': 'Los Angeles',
    'WEST LOS ANGELES': 'Los Angeles',
    'HAWTHORNE': 'Los Angeles',
    'CANYON LAKE': 'Riverside',
    'LAKEWOOD': 'Los Angeles',
    'BIGGS': 'Butte',
    'CLIPPER MILLS': 'Butte',
    'ROSAMOND': 'Kern',
    'ARTESIA': 'Los Angeles',
    'PORTER RANCH': 'Los Angeles',
    'LAKEVIEW TERRACE': 'Los Angeles',
    'LA CAÑADA FLINTRIDGE': 'Los Angeles',
    'LOS NIETOS': 'Los Angeles',
    'LA MIRADA': 'Los Angeles',
    'FLORENCE': 'Los Angeles',
    'WILLOWBROOK': 'Los Angeles',
    'MOUNT WATERMAN': 'Los Angeles',
    'HAWAIIAN GARDENS': 'Los Angeles',
    'VALLEY VILLAGE': 'Los Angeles',
    'ROSEWOOD': 'Los Angeles',
    'THOUSAND PALMS': 'Riverside',
    'RICHVALE': 'Butte',
    'LAKE ELIZABETH': 'Los Angeles',
    'DEL SUR': 'San Diego',
    'FOREST RANCH': 'Butte',
    'PLAYA VISTA': 'Los Angeles',
    'EASTVALE': 'Riverside',
    'CABAZON': 'Riverside',
    'VALYERMO': 'Los Angeles',
    'WHITEWATER': 'Riverside',
    'LAKE HUGHES': 'Los Angeles',
    'ATHENS': 'Los Angeles',
    'SHERMAN OAKS': 'Los Angeles',
    'BASSETT': 'Los Angeles',
    'PARAMOUNT': 'Los Angeles',
    'CITY TERRACE': 'Los Angeles',
    'ELIZABETH LAKE': 'Los Angeles',
    'NUEVO': 'Riverside',
    'ROOSEVELT': 'Los Angeles',
    'MAGALIA': 'Butte',
    'RIPLEY': 'Riverside',
    'VALLEY GLEN': 'Los Angeles',
    'PANORAMA CITY': 'Los Angeles',
    'MOUNT BALDY': 'San Bernardino',
    'LAKE LOS ANGELES': 'Los Angeles',
    'REDMAN': 'San Bernardino',
    'MARCH AIR RESERVE BASE': 'Riverside',
    'LAWNDALE': 'Los Angeles',
    'GARDEN GROVE': 'Orange',
    'LLANO': 'Los Angeles',
    'HUGHES': 'Unknown',
    'ELIZABETH': 'Unknown',
    'GREEN VALLEY': 'Los Angeles',
    'AGOURA HILLS': 'Los Angeles',
    'BUTTE VALLEY': 'Butte',
    'ENCINO': 'Los Angeles',
    'WILSONA': 'Los Angeles',
    'CRYSTALAIRE': 'Los Angeles',
    'BELL GARDENS': 'Los Angeles',
    'WILDOMAR': 'Riverside',
    'MENIFEE': 'Riverside',
    'SEPULVEDA': 'Los Angeles',
    'STIRLING CITY': 'Butte',
    'HIGH VISTA': 'Los Angeles',
    'LAKE BALBOA': 'Los Angeles',
    'FIRESTONE': 'Los Angeles',
    'WINCHESTER': 'Riverside',
    'LAKEVIEW': 'Los Angeles',
    'DOMINGUEZ': 'Los Angeles',
    'RANCHO DOMINGUEZ': 'Los Angeles',
    'INDIO': 'Riverside',
    'FAIR OAKS RANCH': 'Los Angeles',
    'RESEDA': 'Los Angeles',
    'TARZANA': 'Los Angeles',
    'VERNON': 'Los Angeles',
    'SAWMILL MOUNTAIN': 'Unknown',
    'CASTAIC': 'Los Angeles',
    'HUNTINGTON PARK': 'Los Angeles',
    'MONTROSE': 'Los Angeles',
    'DOMINGUEZ HILLS': 'Los Angeles',
    'GORMAN': 'Los Angeles',
    'WINNETKA': 'Los Angeles',
    'WOODLAND HILLS': 'Los Angeles',
    'CANOGA PARK': 'Los Angeles',
    'FERNWOOD': 'Unknown',
    'CHARTER OAK': 'Los Angeles',
    'MALIBU LAKE': 'Los Angeles',
    'SKY VALLEY': 'Riverside',
    'BRENTWOOD': 'Los Angeles',
    'BUTTE MEADOWS': 'Butte',
    'PLACENTIA': 'Orange',
    'QUARTZ HILL': 'Los Angeles',
    'VALENCIA': 'Los Angeles',
    'MALIBU VISTA': 'Los Angeles',
    'ANZA': 'Riverside',
    'WALNUT PARK': 'Los Angeles',
    'SILVER LAKE': 'Los Angeles',
    'LAVERNE': 'Los Angeles',
    'MOUNT GLEASON': 'Los Angeles',
    'WEST HILLS': 'Los Angeles',
    'HOMELAND': 'Riverside',
    'HOLIDAY VALLEY': 'Unknown',
    'WRIGHTWOOD': 'San Bernardino',
    'CHATSWORTH LAKE': 'Los Angeles',
    'CHINO HILLS': 'San Bernardino',
    'HIDDEN HILLS': 'Los Angeles',
    'CORNELL': 'Unknown',
    'LOMIT': 'Unknown',
    'STEVENSON RANCH': 'Los Angeles',
    'WESTRIDGE': 'Unknown',
    'PALOS VERDES': 'Los Angeles',
    'PALOS VERDES PENINSULA': 'Los Angeles',
    'VAL VERDE': 'Los Angeles',
    'VALVERDE': 'Los Angeles',
    'VAL VERDE PARK': 'Los Angeles',
    'JUNIPER HILL': 'Unknown',
    'WEST COMPTON': 'Los Angeles',
    'MAYWOOD': 'Los Angeles',
    'BELL': 'Los Angeles',
    'CUDAHY': 'Los Angeles',
    'VIEW PARK': 'Los Angeles',
    'GLASSELL PARK': 'Los Angeles',
    'LEBEC': 'Kern',
    'AGUANGA': 'Riverside',
    'LEOLA VALLEY': 'Unknown',
    'BERMUDA DUNES': 'Riverside',
    'INDIAN WELLS': 'Riverside',
    'CYPRESS': 'Orange',
    'QUARTZ HILLS': 'Los Angeles',
    'QUARTZ': 'Unknown',
    'FOOTHILL': 'Unknown',
    'NEENACH': 'Los Angeles',
    'PHILLIPS RANCH': 'Los Angeles',
    'DEL AIRE': 'Los Angeles',
    'MOUNTAIN CENTER': 'Riverside',
    'LADERA': 'Los Angeles',
    'WINDSOR HILLS': 'Los Angeles',
    'GLENDALE & BURBANK': 'Los Angeles',
    'NORTH WHITTIER': 'Los Angeles',
    'NELSON': 'Unknown',
    'CALICHE': 'Unknown',
    'EAST RANCHO DOMINGUEZ': 'Los Angeles',
    'LA PALMA': 'Orange',
    'THOUSAND OAKS': 'Ventura',
    'WESTCHESTER': 'Los Angeles',
    'AVOCADO HEIGHTS': 'Los Angeles',
    'NORTH SAN GABRIEL': 'Los Angeles',
    'WATTS': 'Los Angeles',
    'LEON VALLEY': 'Unknown',
    'MOUNT WILSON': 'Los Angeles',
    'ANAVERDE': 'Los Angeles',
    'ALPINE BUTTE': 'San Diego',
    'PEARLAND': 'Unknown',
    'ANTELOPE VALLEY': 'Los Angeles',
    'WHITE FENCE FARM': 'Unknown',
    'HI VISTA': 'Los Angeles',
    'WHITE FENCE FARMS': 'Unknown',
    'ANTELOPE': 'Unknown',
    'VILLAGE': 'Unknown',
    'MT WATERMAN': 'Los Angeles',
    'ALPINE': 'San Diego',
    'HUGHES LAKE': 'Unknown',
    'ANA VERDE': 'San Diego',
    'VACANT': 'Unknown'
}

# %%
sales_df = pd.read_csv('sales_ca.csv')
sales_df.head()

# %%
city_standardization = {
    # Los Angeles variations
    'LOS ANGELES,': 'LOS ANGELES',
    'LOS ANGELES CA 91042': 'LOS ANGELES',
    'LOS ANGELES CA': 'LOS ANGELES',
    'LOS ANGELES C': 'LOS ANGELES',
    'LOS ANGELES CALIF': 'LOS ANGELES',
    'LOS ANGELRES': 'LOS ANGELES',
    'LOS ANGLES': 'LOS ANGELES',
    'LOS ANGELS': 'LOS ANGELES',
    'LOS ANGELE': 'LOS ANGELES',
    'LOS ANAGELES': 'LOS ANGELES',
    'LOS ANGGELES': 'LOS ANGELES',
    'LOS ANGES': 'LOS ANGELES',
    'LOSANGELES,': 'LOS ANGELES',
    'L A': 'LOS ANGELES',
    'LA': 'LOS ANGELES',
    
    # Palmdale variations
    'PALMDLE': 'PALMDALE',
    'PALDMALE': 'PALMDALE',
    'PALMDALE CA': 'PALMDALE',
    'PALMDALE CALIF': 'PALMDALE',
    'PALMDALE CAL': 'PALMDALE',
    'PAMLDALE': 'PALMDALE',
    'PALMADALE': 'PALMDALE',
    'PALAMDALE': 'PALMDALE',
    'PLAMDALE': 'PALMDALE',
    'W PALMDALE': 'PALMDALE',
    'WEST PALMDALE': 'PALMDALE',
    
    # Santa Clarita variations
    'SANTA CLARIT': 'SANTA CLARITA',
    'SANTA CLARITA WAY': 'SANTA CLARITA',
    'SANTA CLARITA V': 'SANTA CLARITA',
    'SANTA CLARITA PL': 'SANTA CLARITA',
    'SANTA CLARITA CA,': 'SANTA CLARITA',
    'SANTA LARITA': 'SANTA CLARITA',
    'SANA CLARITA': 'SANTA CLARITA',
    'SANAT CLARITA': 'SANTA CLARITA',
    
    # Burbank variations
    'BURBANK,': 'BURBANK',
    'BURBANK CALIF': 'BURBANK',
    'BURBANK CA': 'BURBANK',
    'BURBANK CA-': 'BURBANK',
    
    # Long Beach variations
    'LONG BEACH,': 'LONG BEACH',
    'LONG BEACH CA': 'LONG BEACH',
    'LONG BEACH CALIFORNI': 'LONG BEACH',
    'LONGBEACH': 'LONG BEACH',
    
    # Glendale variations
    'GLENDALE,': 'GLENDALE',
    'GLANDALE': 'GLENDALE',
    'GLENOALE': 'GLENDALE',
    'GLENDA': 'GLENDALE',
    
    # Whittier variations
    'WHITTIER,': 'WHITTIER',
    'WHITTIER/': 'WHITTIER',
    'WHITTIER CA': 'WHITTIER',
    'WHITIIER': 'WHITTIER',
    'WHITWOOD': 'WHITTIER',
    'WHITTIE': 'WHITTIER',
    
    # Hacienda Heights variations
    'HACIENDA HGHTS': 'HACIENDA HEIGHTS',
    'HACIENDA HTS': 'HACIENDA HEIGHTS',
    'HACIENDA HEIGTHS': 'HACIENDA HEIGHTS',
    'HACIENDA HIEGHTS': 'HACIENDA HEIGHTS',
    'HACIENDA HEIGHT': 'HACIENDA HEIGHTS',
    'HACIENDA HEIGHTS C': 'HACIENDA HEIGHTS',
    'HACINDA HEIGHTS': 'HACIENDA HEIGHTS',
    'HACIENDAHEIGHTS': 'HACIENDA HEIGHTS',
    'HACIENA HEIGHTS': 'HACIENDA HEIGHTS',
    'HCIENDA HEIGHTS': 'HACIENDA HEIGHTS',
    
    # Rowland Heights variations
    'ROWLAND HGHTS': 'ROWLAND HEIGHTS',
    'ROWLAND HTS': 'ROWLAND HEIGHTS',
    'ROWLAND HGTS': 'ROWLAND HEIGHTS',
    'ROWLAND HEIGHT': 'ROWLAND HEIGHTS',
    'ROWLAND HEIGTHS': 'ROWLAND HEIGHTS',
    'ROWLAND HEUGHTS': 'ROWLAND HEIGHTS',
    'ROWLAN HEIGHTS': 'ROWLAND HEIGHTS',
    'RORLAND HEIGHTS': 'ROWLAND HEIGHTS',
    'ROWLAND HEIGHTS CCA': 'ROWLAND HEIGHTS',
    
    # La Cañada Flintridge variations
    'LA CANADA FLINTRIDGE': 'LA CANADA FLINTRIDGE',
    'LA CANAD-FLNTRDG': 'LA CANADA FLINTRIDGE',
    'LA CANADA': 'LA CANADA FLINTRIDGE',
    'LA CANADA FLT': 'LA CANADA FLINTRIDGE',
    'LA CANADA FLT CA': 'LA CANADA FLINTRIDGE',
    'LA CANADA FL CA': 'LA CANADA FLINTRIDGE',
    'LA CANADA FLINT': 'LA CANADA FLINTRIDGE',
    'LA CANADA FLINTRIGE': 'LA CANADA FLINTRIDGE',
    'LA CANANDA FLT': 'LA CANADA FLINTRIDGE',
    'LA CANADA FLINTRUDGE': 'LA CANADA FLINTRIDGE',
    
    # Rolling Hills Estates variations
    'ROLLING HILLS ES': 'ROLLING HILLS ESTATES',
    'ROLLING HILLS EST': 'ROLLING HILLS ESTATES',
    'ROLLING HILLS ESTAT': 'ROLLING HILLS ESTATES',
    'ROLLING HILLS ESTATE': 'ROLLING HILLS ESTATES',
    'ROLL HILLS ESTATES': 'ROLLING HILLS ESTATES',
    'ROLLING HILLS ESTS': 'ROLLING HILLS ESTATES',
    'RLLNG HLS EST': 'ROLLING HILLS ESTATES',
    'RLNG HLS EST': 'ROLLING HILLS ESTATES',
    'RLLNG HLS ES': 'ROLLING HILLS ESTATES',
    
    # Manhattan Beach variations
    'MANHATTAN BCH': 'MANHATTAN BEACH',
    'MANHATTAN BCH,': 'MANHATTAN BEACH',
    'MANHATTANBEACH': 'MANHATTAN BEACH',
    
    # South Gate variations
    'SOUTHGATE': 'SOUTH GATE',
    'SOUTH GATE,': 'SOUTH GATE',
    'SOUTH GATE/': 'SOUTH GATE',
    'SOUTH GATE CALIF': 'SOUTH GATE',
    'SO GATE': 'SOUTH GATE',
    
    # South El Monte variations
    'SO EL MONTE': 'SOUTH EL MONTE',
    'S EL MONTE': 'SOUTH EL MONTE',
    'SO. EL MONTE': 'SOUTH EL MONTE',
    'S. EL MONTE': 'SOUTH EL MONTE',
    
    # North Hollywood variations
    'N HOLLYWOOD': 'NORTH HOLLYWOOD',
    'NO HOLLYWOOD': 'NORTH HOLLYWOOD',
    'N. HOLLYWOOD': 'NORTH HOLLYWOOD',
    'NORTH HOLLYWOOD,': 'NORTH HOLLYWOOD',
    'NORTH HOLLYWOOD CALIF': 'NORTH HOLLYWOOD',
    
    # Santa Monica variations
    'SANTA MONI': 'SANTA MONICA',
    'SANTA MONICA,': 'SANTA MONICA',
    'SANTA MONICA CALIF': 'SANTA MONICA',
    
    # Marina del Rey variations
    'MARINA DE REY': 'MARINA DEL REY',
    'MARINA DEL RY': 'MARINA DEL REY',
    'MARNIA DEL REY': 'MARINA DEL REY',
    
    # Woodland Hills variations
    'WOODLAND HLS': 'WOODLAND HILLS',
    'WOODLAND HILLS CALIF': 'WOODLAND HILLS',
    
    # Palos Verdes variations
    'PALOS VERDES PNSLA': 'PALOS VERDES',
    'PALOS VERDES PEN': 'PALOS VERDES',
    'PALOS VERDES PENNS': 'PALOS VERDES',
    'PALOS VERDES PENN': 'PALOS VERDES',
    'PALOS VERDES ESTATE': 'PALOS VERDES ESTATES',
    'PLS VRDS PNSL': 'PALOS VERDES',
    'PLS VRDS PNSLA': 'PALOS VERDES',
    'PALOS VRDS PNSL': 'PALOS VERDES',
    
    # Rancho Palos Verdes variations
    'RANCHO PALOS VERDE': 'RANCHO PALOS VERDES',
    'RANCHO PALOS VERD': 'RANCHO PALOS VERDES',
    'RCH PALOS VERDES': 'RANCHO PALOS VERDES',
    'RCH PALOS VRDS': 'RANCHO PALOS VERDES',
    'RCH PALOS VRD': 'RANCHO PALOS VERDES',
    'RNCHO PALOS VRDS': 'RANCHO PALOS VERDES',
    'RNCHO PLS VRD': 'RANCHO PALOS VERDES',
    
    # West Hollywood variations
    'W HOLLYWOOD': 'WEST HOLLYWOOD',
    'WEST HOLLYWOO': 'WEST HOLLYWOOD',
    'WEST HOLLYWOOD,': 'WEST HOLLYWOOD',
    '9EST HOLLYWOOD': 'WEST HOLLYWOOD',
    'WWEST HOLLYWOOD': 'WEST HOLLYWOOD',
    
    # Additional common variations
    'ELMONTE': 'EL MONTE',
    'E LOS ANGELES': 'EAST LOS ANGELES',
    'EAST LOS ANGELE': 'EAST LOS ANGELES',
    'REDONDO BCH': 'REDONDO BEACH',
    'REDONDO BCH,': 'REDONDO BEACH',
    'REDONDO BEACH,': 'REDONDO BEACH',
    'HERMOSA BCH': 'HERMOSA BEACH',
    'HERMOSA BCH,': 'HERMOSA BEACH',
    'CULVERCITY': 'CULVER CITY',
    'CULVER CITY,': 'CULVER CITY',
    
    # Lancaster variations
    'LANCASTERC': 'LANCASTER',
    'LANCASTER CAELES': 'LANCASTER',
    'LANCASTER,': 'LANCASTER',
    'LANCASTER (LAKE LA)': 'LANCASTER',
    'LANASTER': 'LANCASTER',
    'LANCASTE': 'LANCASTER',
    'LANCATER': 'LANCASTER',
    'LACASTER': 'LANCASTER',
    'LANACASTER': 'LANCASTER',
    
    # Valencia variations
    'VALENCIA,': 'VALENCIA',
    'VALENCIA CALIF': 'VALENCIA',
    'VALENCIA CALIFORNI': 'VALENCIA',
    'VELENCIA': 'VALENCIA',
    
    # Calabasas variations
    'CALABASSAS': 'CALABASAS',
    'CALABASAL': 'CALABASAS',
    'CALABASAS CAL': 'CALABASAS',
    'CALABASAS HILLS': 'CALABASAS',
    
    # Lake Los Angeles variations
    'LAKE LA': 'LAKE LOS ANGELES',
    'LAKE L A': 'LAKE LOS ANGELES',
    'LAK LOS ANGELES': 'LAKE LOS ANGELES',
    'LAKE LOS ANGELE': 'LAKE LOS ANGELES',
    'LAKE LOS ANGELES,': 'LAKE LOS ANGELES',
    'LAKE LOS ANGELS': 'LAKE LOS ANGELES',
    'LAKE LSO ANGELES': 'LAKE LOS ANGELES',
    'LOKE LOS ANGELE': 'LAKE LOS ANGELES',
    'LAKE LOS ANGLES': 'LAKE LOS ANGELES',
    
    # Stevenson Ranch variations
    'STEVENSON RNH': 'STEVENSON RANCH',
    'STEVENSON': 'STEVENSON RANCH',
    'STENSON RANCH': 'STEVENSON RANCH',
    
    # La Crescenta variations
    'LA CRESENTA': 'LA CRESCENTA',
    'LA CRECENTA': 'LA CRESCENTA',
    'LA CRESCENT': 'LA CRESCENTA',
    'LA CRESCENTA,': 'LA CRESCENTA',
    'LACRESCENTA': 'LA CRESCENTA',
    
    # Topanga variations
    'TOPANGA,': 'TOPANGA',
    'TOPANG': 'TOPANGA',
    'TOPANGA CA': 'TOPANGA',
    'TOPANGA CANYON': 'TOPANGA',
    'TOPANGA CYN': 'TOPANGA',
    'TOPONGA': 'TOPANGA',
    
    # Westlake Village variations
    'WESTLAKE VILLG': 'WESTLAKE VILLAGE',
    'WESTLAKE VLG': 'WESTLAKE VILLAGE',
    'WEST LAKE VILLAGE': 'WESTLAKE VILLAGE',
    
    # Sun Village variations
    'SUN VILLLAGE': 'SUN VILLAGE',
    'SUNVILLAGE': 'SUN VILLAGE',
    'SUN VILLAAGE': 'SUN VILLAGE',
    'SUN VILLAGAE': 'SUN VILLAGE',
    'SUN VALLAGE': 'SUN VILLAGE',
    'SUN VILAGE': 'SUN VILLAGE',
    'SUN VIILAGE': 'SUN VILLAGE',
    'SU VILLAGE': 'SUN VILLAGE',
    'SIN VILLAGE': 'SUN VILLAGE',
    
    # Antelope Acres variations
    'ANTLEOPE ACRES': 'ANTELOPE ACRES',
    'ANTELOPOE ACRES': 'ANTELOPE ACRES',
    'ANTELOPE ACRSE': 'ANTELOPE ACRES',
    'ANTELOPE ACRS': 'ANTELOPE ACRES',
    'ANETLOPE ACRES': 'ANTELOPE ACRES',
    'ANTLOPE ACRES': 'ANTELOPE ACRES',
    'ANTELOPE AVRES': 'ANTELOPE ACRES',
    
    # Pearblossom variations
    'PEARBLASSOM': 'PEARBLOSSOM',
    'PEARBLOSSOOM': 'PEARBLOSSOM',
    'PEARBLOSSSOM': 'PEARBLOSSOM',
    'PEARBLOSOM': 'PEARBLOSSOM',
    'PEARBLOOSOM': 'PEARBLOSSOM',
    'PEARLBLOSSM': 'PEARBLOSSOM',
    'PEARBLOSSON': 'PEARBLOSSOM',
    'PEALBLOSSOM': 'PEARBLOSSOM',
    'PEARBLOOM': 'PEARBLOSSOM',
    'PEARBLOSSOM RD': 'PEARBLOSSOM',
    
    # Elizabeth Lake variations
    'ELIZABETH LK': 'ELIZABETH LAKE',
    'ELIZABETJ LK': 'ELIZABETH LAKE',
    'EIZABETH LK': 'ELIZABETH LAKE',
    'EIZABETH LAKE': 'ELIZABETH LAKE',
    'ELIZAABETH LAKE': 'ELIZABETH LAKE',
    'ELIZABETH LK DR': 'ELIZABETH LAKE',
    'ELIZABETH HILL': 'ELIZABETH LAKE',
    'LK ELIZABETH': 'ELIZABETH LAKE',
    
    # Agua Dulce variations
    'AGUA DULCA': 'AGUA DULCE',
    'AGUA DULE': 'AGUA DULCE',
    'AGUA DUICE': 'AGUA DULCE',
    'AQUA DULCE': 'AGUA DULCE',
    'AGUD DULCE': 'AGUA DULCE',
    'AGAU DULCE': 'AGUA DULCE',
    'AGUADULCE': 'AGUA DULCE',
    'AFUA DULCE': 'AGUA DULCE',
    
    # Additional Cities and Variations
    'HAWAIIAN GARDNS': 'HAWAIIAN GARDENS',
    'HAWAIIAN GDNS': 'HAWAIIAN GARDENS',
    'HAWAIIAN GRADENS': 'HAWAIIAN GARDENS',
    
    'HUNTINGTON PK': 'HUNTINGTON PARK',
    'HUNTINGTON PARK,': 'HUNTINGTON PARK',
    
    'PACIFIC PALISAADES': 'PACIFIC PALISADES',
    'PACIFIC PALASADES': 'PACIFIC PALISADES',
    'PACIFIC PALISADE': 'PACIFIC PALISADES',
    'PACIFIC PLSDS': 'PACIFIC PALISADES',
    
    'BALDWIN PK': 'BALDWIN PARK',
    
    'MONTEREY PRK': 'MONTEREY PARK',
    'MONTEREY  PARK': 'MONTEREY PARK',
    'MONTEREY PK': 'MONTEREY PARK',
    
    'RANCHO DOMIGUEZ': 'RANCHO DOMINGUEZ',
    'RNCHO DOMINGZ': 'RANCHO DOMINGUEZ',
    'DOMNINGUEZ': 'RANCHO DOMINGUEZ',
    'DOMINGUEZ': 'RANCHO DOMINGUEZ',
    'DOMINGUES': 'RANCHO DOMINGUEZ',
    
    'MONROVI': 'MONROVIA',
    'TORRANCE,': 'TORRANCE',
    'TRRANCE': 'TORRANCE',
    
    'COMPTON,': 'COMPTON',
    'COMPTON/': 'COMPTON',
    'COPMPTON': 'COMPTON',
    'COMTON': 'COMPTON',
    
    'MOUNT WILSON CALIF': 'MOUNT WILSON',
    'MT WILSON CALIF': 'MOUNT WILSON',
    
    'MOUNT WATERMAN': 'MT WATERMAN',
    'MOUNT WATEMAN': 'MT WATERMAN',
    'MONT WATERMAN': 'MT WATERMAN',
    
    'CASTAI': 'CASTAIC',
    'CASTICC': 'CASTAIC',
    
    'LLANO,': 'LLANO',
    'LLAMO': 'LLANO',
    'LLAND': 'LLANO',
    'LIANO': 'LLANO',
    
    'ACTON,': 'ACTON',
    'ACTION': 'ACTON',
    
    'VALYERNO': 'VALYERMO',
    'VALLYERMO': 'VALYERMO',
    
    'GLENDOR': 'GLENDORA',
    
    'ALHAMBR': 'ALHAMBRA',
    
    'TEMPLE CIT': 'TEMPLE CITY',
    
    'COVIN': 'COVINA',
    
    'AZUS': 'AZUSA',
    
    'ARTESIA,': 'ARTESIA',
    'ARETESIA,': 'ARTESIA',
    
    'CERRITOS,': 'CERRITOS',
    'CERRITOS/': 'CERRITOS',
    
    'PARAMOUNT,': 'PARAMOUNT',
    
    'BELL,': 'BELL',
    
    'BELL GARDENS,': 'BELL GARDENS',
    
    'SOUTH GATE/CALIFORNI': 'SOUTH GATE',
    'FORBESTOWN': 'FORBESTOWN',
    'ROWLAND HEIGHTS': 'ROWLAND HEIGHTS',
    'EL MONTE / CALIFORNI': 'EL MONTE',
    'SAN VALLEY': 'SAN FERNANDO VALLEY',
    'KAGEL CANYON': 'KAGEL CANYON',
    'LOS ANGLELS': 'LOS ANGELES',
    'WEST LOS ANGELES': 'WEST LOS ANGELES',
    'HAWTHORNE': 'HAWTHORNE',
    'CANYON LAKE': 'CANYON LAKE',
    'LAKEWOOD': 'LAKEWOOD',
    'BIGGS': 'BIGGS',
    'CLIPPER MILLS': 'CLIPPER MILLS',
    'ROSAMOND': 'ROSAMOND',
    'ARTESIA': 'ARTESIA',
    'PORTER RANCH': 'PORTER RANCH',
    'SANTA FE SPRNGS': 'SANTA FE SPRINGS',
    'PACOIM': 'PACOIMA',
    'LAKEVIEW TERRACE': 'LAKEVIEW TERRACE',
    'ALTA DENA': 'ALTADENA',
    'LA CANADA-FLINTRIDGE': 'LA CAÑADA FLINTRIDGE',
    'LYNWOOD,': 'LYNWOOD',
    'WILMINGTON V': 'WILMINGTON',
    'LOS NIETOS': 'LOS NIETOS',
    'LA MIRADA': 'LA MIRADA',
    'FLORENCE': 'FLORENCE',
    'WILLOWBROOK': 'WILLOWBROOK',
    'MT WATERMAN': 'MOUNT WATERMAN',
    'HAWAIIAN GARDENS': 'HAWAIIAN GARDENS',
    'NORWALK/': 'NORWALK',
    'VALLEY VILLAGE': 'VALLEY VILLAGE',
    'SYLMAR CA': 'SYLMAR',
    'ROLLING HILS': 'ROLLING HILLS',
    'ROSEWOOD': 'ROSEWOOD',
    'W COVINA': 'WEST COVINA',
    'THOUSAND PALMS': 'THOUSAND PALMS',
    'RICHVALE': 'RICHVALE',
    'S PASADENA': 'SOUTH PASADENA',
    'LAKE ELIZABETH': 'LAKE ELIZABETH',
    'LA HABRA HTS': 'LA HABRA HEIGHTS',
    'SO. SAN GABRIEL': 'SOUTH SAN GABRIEL',
    'DEL SUR': 'DEL SUR',
    'FOREST RANCH': 'FOREST RANCH',
    'PLAYA VISTA': 'PLAYA VISTA',
    'EASTVALE': 'EASTVALE',
    'LA PUENTE CA': 'LA PUENTE',
    'SO.PASADENA': 'SOUTH PASADENA',
    'CABAZON': 'CABAZON',
    'VALYERMO': 'VALYERMO',
    'WHITE WATER': 'WHITEWATER',
    'LAKE HUGHES': 'LAKE HUGHES',
    'ATHENS': 'ATHENS',
    'SHERMAN OAKS': 'SHERMAN OAKS',
    'HAWTHORNE BLVD': 'HAWTHORNE BLVD',
    'BASSETT': 'BASSETT',
    'VENICE,': 'VENICE',
    'PARAMOUNT': 'PARAMOUNT',
    'CITY TERRACE': 'CITY TERRACE',
    'SAN DIAMS': 'SAN DIMAS',
    'ELIZABETH LAKE': 'ELIZABETH LAKE',
    'BASSET': 'BASSETT',
    'NUEVO': 'NUEVO',
    'ROOSEVELT': 'ROOSEVELT',
    'LA SAN PEDRO': 'SAN PEDRO',
    'MAGALIA': 'MAGALIA',
    'SANTA FE SPRINGS CALIF': 'SANTA FE SPRINGS',
    'VAN NUYS CALIF': 'VAN NUYS',
    'RIPLEY': 'RIPLEY',
    'VALLEY GLEN': 'VALLEY GLEN',
    'PANORAMA CITY': 'PANORAMA CITY',
    'CANYON CNTRY': 'CANYON COUNTRY',
    'MOUNT BALDY': 'MOUNT BALDY',
    'HAWAIIAN GARDENS,': 'HAWAIIAN GARDENS',
    'SO SAN GABRIEL': 'SOUTH SAN GABRIEL',
    'LAKE LOS ANGELES': 'LAKE LOS ANGELES',
    'REDMAN': 'REDMAN',
    'MARCH ARB': 'MARCH AIR RESERVE BASE',
    'LAKE HUGES': 'LAKE HUGHES',
    'LAWNDALE': 'LAWNDALE',
    'GARDEN': 'GARDEN GROVE',
    'RANCHO PALOS VRDS': 'RANCHO PALOS VERDES',
    'WHITIER': 'WHITTIER',
    'LLANO': 'LLANO',
    'S PASADEN': 'SOUTH PASADENA',
    'HACIENDA HGTS': 'HACIENDA HEIGHTS',
    'HUGHES': 'HUGHES',
    'LA HABRA HGHTS': 'LA HABRA HEIGHTS',
    'VAN NUYS,': 'VAN NUYS',
    'LOS ANGELES, CA 90042': 'LOS ANGELES',
    'ELIZABETH': 'ELIZABETH',
    'LA MIRADA,': 'LA MIRADA',
    'VALINDA,': 'VALINDA',
    'GREEN VALLEY': 'GREEN VALLEY',
    'AGOURA': 'AGOURA HILLS',
    'PASADEN': 'PASADENA',
    'S SAN GABRIEL': 'SOUTH SAN GABRIEL',
    'BUTTE VALLEY': 'BUTTE VALLEY',
    'LAMIRADA': 'LA MIRADA',
    'LA HABRA HGTS': 'LA HABRA HEIGHTS',
    'LOS ANGELES CA.': 'LOS ANGELES',
    'ENCINO': 'ENCINO',
    'LA MIRAD': 'LA MIRADA',
    'WILSONA': 'WILSONA',
    'CRYSTALAIRE': 'CRYSTALAIRE',
    'LOS ANGELES (SYLMAR)': 'SYLMAR',
    'AGOURA HILLS': 'AGOURA HILLS',
    'SOUTH SAN GABRIE': 'SOUTH SAN GABRIEL',
    'BELL GARDENS': 'BELL GARDENS',
    'WILDOMAR': 'WILDOMAR',
    'MALIBU CALIF': 'MALIBU',
    'BELLFLOWER AVE': 'BELLFLOWER',
    'MENIFEE': 'MENIFEE',
    'SAUGU': 'SAUGUS',
    'CANYON COUNTR': 'CANYON COUNTRY',
    'SEPULVEDA': 'SEPULVEDA',
    'STIRLING CITY': 'STIRLING CITY',
    'HIGH VISTA': 'HIGH VISTA',
    'LAKE BALBOA': 'LAKE BALBOA',
    'SOUTH SAN GRABRIEL': 'SOUTH SAN GABRIEL',
    'FIRESTONE': 'FIRESTONE',
    'WINCHESTER': 'WINCHESTER',
    'LAKEVIEW': 'LAKEVIEW',
    'RANCHO DOMINGUEZ': 'RANCHO DOMINGUEZ',
    'ENCINO,': 'ENCINO',
    'INDIO': 'INDIO',
    'CARSON ST': 'CARSON',
    'FAIR OAKS RANCH': 'FAIR OAKS RANCH',
    'RESEDA': 'RESEDA',
    'CARSON CALIF': 'CARSON',
    'TARZANA': 'TARZANA',
    'VERNON': 'VERNON',
    'SAWMILL MTN': 'SAWMILL MOUNTAIN',
    'ROWLAND HGHTS CA': 'ROWLAND HEIGHTS',
    'ROWLAND HEGHTS': 'ROWLAND HEIGHTS',
    'CASTAIC': 'CASTAIC',
    'HUNTINGTON PARK': 'HUNTINGTON PARK',
    'MONTROSE': 'MONTROSE',
    'DOMINGUEZ HILLS': 'DOMINGUEZ HILLS',
    'GORMAN': 'GORMAN',
    'WEST COVIN': 'WEST COVINA',
    'WINNETKA': 'WINNETKA',
    'DOMIGUEZ': 'DOMINGUEZ',
    'WOODLAND HILLS': 'WOODLAND HILLS',
    'CANOGA PARK': 'CANOGA PARK',
    'SIGNAL HILL,': 'SIGNAL HILL',
    'WILLOWBROOKS': 'WILLOWBROOK',
    'FERNWOOD': 'FERNWOOD',
    'CHARTER OAK': 'CHARTER OAK',
    'MALIBU LAKE': 'MALIBU LAKE',
    'SKY VALLEY': 'SKY VALLEY',
    'BRENTWOOD': 'BRENTWOOD',
    'BUTTE MEADOWS': 'BUTTE MEADOWS',
    'PLACENTIA': 'PLACENTIA',
    'LA PUENTA': 'LA PUENTE',
    'QUARTZ HILL': 'QUARTZ HILL',
    'VALENCIA': 'VALENCIA',
    'MALIBU VIST': 'MALIBU VISTA',
    'ANZA': 'ANZA',
    'SAN PEDRO,': 'SAN PEDRO',
    'WALNUT PARK': 'WALNUT PARK',
    'SILVERADO CANYON': 'SILVERADO CANYON',
    'SHERMAN OAKS, CA': 'SHERMAN OAKS',
    'ACTON CA': 'ACTON',
    'WILMINGTON 90744': 'WILMINGTON',
    'BUTTE VALLEY V': 'BUTTE VALLEY',
    'PERLBLOSSOM': 'PEARLBLOSSOM',
    'HI VISATA': 'HI VISTA',
    'SAWHILL MOUNTAIN': 'SAWMILL MOUNTAIN',
    'ROOSVELTT': 'ROOSEVELT',
    'SAWMILL MT': 'SAWMILL MOUNTAIN',
    'LOS ANGELES/': 'LOS ANGELES',
    'SOUTH GATE /': 'SOUTH GATE',
    'BLACK BUTTE CA`': 'BLACK BUTTE',
    'HI VIST': 'HI VISTA',
    'SAWHILL MT': 'SAWMILL MOUNTAIN',
    'ROOSVELT': 'ROOSEVELT',
    'ALINE BUTTE': 'ALPINE BUTTE',
    'SAWMILL MOUNTAIN RD': 'SAWMILL MOUNTAIN',
    'REDMAN AVE': 'REDMAN',
    'SAWHILL MOUNTAIN': 'SAWMILL MOUNTAIN',
    'FORBESTOWN': 'FORBESTOWN',
    'ROWLAND HEIGHTS': 'ROWLAND HEIGHTS',
    'SAN FERNANDO VALLEY': 'SAN FERNANDO VALLEY',
    'KAGEL CANYON': 'KAGEL CANYON',
    'WEST LOS ANGELES': 'WEST LOS ANGELES',
    'HAWTHORNE': 'HAWTHORNE',
    'CANYON LAKE': 'CANYON LAKE',
    'LAKEWOOD': 'LAKEWOOD',
    'BIGGS': 'BIGGS',
    'CLIPPER MILLS': 'CLIPPER MILLS',
    'ROSAMOND': 'ROSAMOND',
    'ARTESIA': 'ARTESIA',
    'PORTER RANCH': 'PORTER RANCH',
    'LAKEVIEW TERRACE': 'LAKEVIEW TERRACE',
    'LA CAÑADA FLINTRIDGE': 'LA CAÑADA FLINTRIDGE',
    'LOS NIETOS': 'LOS NIETOS',
    'LA MIRADA': 'LA MIRADA',
    'FLORENCE': 'FLORENCE',
    'WILLOWBROOK': 'WILLOWBROOK',
    'MOUNT WATERMAN': 'MOUNT WATERMAN',
    'HAWAIIAN GARDENS': 'HAWAIIAN GARDENS',
    'VALLEY VILLAGE': 'VALLEY VILLAGE',
    'ROSEWOOD': 'ROSEWOOD',
    'THOUSAND PALMS': 'THOUSAND PALMS',
    'RICHVALE': 'RICHVALE',
    'LAKE ELIZABETH': 'LAKE ELIZABETH',
    'DEL SUR': 'DEL SUR',
    'FOREST RANCH': 'FOREST RANCH',
    'PLAYA VISTA': 'PLAYA VISTA',
    'EASTVALE': 'EASTVALE',
    'CABAZON': 'CABAZON',
    'VALYERMO': 'VALYERMO',
    'WHITEWATER': 'WHITEWATER',
    'LAKE HUGHES': 'LAKE HUGHES',
    'ATHENS': 'ATHENS',
    'SHERMAN OAKS': 'SHERMAN OAKS',
    'HAWTHORNE BLVD': 'HAWTHORNE',
    'BASSETT': 'BASSETT',
    'PARAMOUNT': 'PARAMOUNT',
    'CITY TERRACE': 'CITY TERRACE',
    'ELIZABETH LAKE': 'ELIZABETH LAKE',
    'NUEVO': 'NUEVO',
    'ROOSEVELT': 'ROOSEVELT',
    'MAGALIA': 'MAGALIA',
    'RIPLEY': 'RIPLEY',
    'VALLEY GLEN': 'VALLEY GLEN',
    'PANORAMA CITY': 'PANORAMA CITY',
    'MOUNT BALDY': 'MOUNT BALDY',
    'LAKE LOS ANGELES': 'LAKE LOS ANGELES',
    'REDMAN': 'REDMAN',
    'MARCH AIR RESERVE BASE': 'MARCH AIR RESERVE BASE',
    'LAWNDALE': 'LAWNDALE',
    'GARDEN GROVE': 'GARDEN GROVE',
    'LLANO': 'LLANO',
    'HUGHES': 'HUGHES',
    'ELIZABETH': 'ELIZABETH',
    'GREEN VALLEY': 'GREEN VALLEY',
    'AGOURA HILLS': 'AGOURA HILLS',
    'BUTTE VALLEY': 'BUTTE VALLEY',
    'ENCINO': 'ENCINO',
    'MT WATERMAN': 'MOUNT WATERMAN',
    'WILSONA': 'WILSONA',
    'CRYSTALAIRE': 'CRYSTALAIRE',
    'BELL GARDENS': 'BELL GARDENS',
    'WILDOMAR': 'WILDOMAR',
    'MENIFEE': 'MENIFEE',
    'SEPULVEDA': 'SEPULVEDA',
    'STIRLING CITY': 'STIRLING CITY',
    'HIGH VISTA': 'HIGH VISTA',
    'LAKE BALBOA': 'LAKE BALBOA',
    'FIRESTONE': 'FIRESTONE',
    'WINCHESTER': 'WINCHESTER',
    'LAKEVIEW': 'LAKEVIEW',
    'RANCHO DOMINGUEZ': 'RANCHO DOMINGUEZ',
    'INDIO': 'INDIO',
    'FAIR OAKS RANCH': 'FAIR OAKS RANCH',
    'RESEDA': 'RESEDA',
    'TARZANA': 'TARZANA',
    'VERNON': 'VERNON',
    'SAWMILL MOUNTAIN': 'SAWMILL MOUNTAIN',
    'CASTAIC': 'CASTAIC',
    'HUNTINGTON PARK': 'HUNTINGTON PARK',
    'MONTROSE': 'MONTROSE',
    'DOMINGUEZ HILLS': 'DOMINGUEZ HILLS',
    'GORMAN': 'GORMAN',
    'WINNETKA': 'WINNETKA',
    'DOMINGUEZ': 'DOMINGUEZ',
    'WOODLAND HILLS': 'WOODLAND HILLS',
    'CANOGA PARK': 'CANOGA PARK',
    'FERNWOOD': 'FERNWOOD',
    'CHARTER OAK': 'CHARTER OAK',
    'MALIBU LAKE': 'MALIBU LAKE',
    'SKY VALLEY': 'SKY VALLEY',
    'BRENTWOOD': 'BRENTWOOD',
    'BUTTE MEADOWS': 'BUTTE MEADOWS',
    'PLACENTIA': 'PLACENTIA',
    'QUARTZ HILL': 'QUARTZ HILL',
    'VALENCIA': 'VALENCIA',
    'MALIBU VISTA': 'MALIBU VISTA',
    'ANZA': 'ANZA',
    'WALNUT PARK': 'WALNUT PARK',
    'SILVER LAKE': 'SILVER LAKE',
    'LAVERNE': 'LAVERNE',
    'MOUNT GLEASON': 'MOUNT GLEASON',
    'WEST HILLS': 'WEST HILLS',
    'HOMELAND': 'HOMELAND',
    'HOLIDAY VALLEY': 'HOLIDAY VALLEY',
    'WRIGHTWOOD': 'WRIGHTWOOD',
    'CHATSWORTH LAKE': 'CHATSWORTH LAKE',
    'CHINO HILLS': 'CHINO HILLS',
    'HARBOR CITY,': 'HARBOR CITY',
    'HIDDEN HILLS': 'HIDDEN HILLS',
    'CORNELL': 'CORNELL',
    'LOMIT': 'LOMIT',
    'WESTHILLS': 'WEST HILLS',
    'STEVENSON RANCH': 'STEVENSON RANCH',
    'HARBOR CTIY': 'HARBOR CITY',
    'MALIBU,': 'MALIBU',
    'WESTRIDGE': 'WESTRIDGE',
    'PALOS VERDES': 'PALOS VERDES',
    'WRIGHT WOOD': 'WRIGHTWOOD',
    'PALOS VERDES PNSL': 'PALOS VERDES PENINSULA',
    'VAL VERDE': 'VAL VERDE',
    'VALVERDE': 'VALVERDE',
    'LA CESCENT': 'LA CRESCENTA',
    'VAL VERDE PARK': 'VAL VERDE PARK',
    'JUNIPER HILL': 'JUNIPER HILL',
    'WEST COMPTON': 'WEST COMPTON',
    'PASADENA CALIF': 'PASADENA',
    'PLAYA DEL REY,': 'PLAYA DEL REY',
    'MAYWOOD': 'MAYWOOD',
    'BELL': 'BELL',
    'CUDAHY': 'CUDAHY',
    'VIEW PARK': 'VIEW PARK',
    'GLASSELL PARK': 'GLASSELL PARK',
    'LEBEC': 'LEBEC',
    'ALTADEN': 'ALTADENA',
    'AGUANGA': 'AGUANGA',
    'LEOLA VALLEY': 'LEOLA VALLEY',
    'HI VISTA': 'HIGH VISTA',
    'BERMUDA DUNES': 'BERMUDA DUNES',
    'QUARTE HILL': 'QUARTZ HILL',
    'INDIAN WELLS': 'INDIAN WELLS',
    'CYPRESS': 'CYPRESS',
    'QUARTZ HILLS': 'QUARTZ HILLS',
    'QUARTZ': 'QUARTZ',
    'ST, BIGGS': 'BIGGS',
    'INGLEWOOD,': 'INGLEWOOD',
    'LA CANADA FLT CA T': 'LA CAÑADA FLINTRIDGE',
    'CUDAHAY': 'CUDAHY',
    'FOOTHILL': 'FOOTHILL',
    'HAWTHORNE,': 'HAWTHORNE',
    'LOS ANGELES, CA 90032': 'LOS ANGELES',
    'NEENACH': 'NEENACH',
    'PHILLIPS RANCH': 'PHILLIPS RANCH',
    'QUARTZ HILL,': 'QUARTZ HILL',
    'HAWTHRONE': 'HAWTHORNE',
    'SAN GRABRIEL': 'SAN GABRIEL',
    'DEL AIRE': 'DEL AIRE',
    'LA VERN': 'LA VERNE',
    'LOS ANGELES CA 00': 'LOS ANGELES',
    'MOUNTAIN CENTER': 'MOUNTAIN CENTER',
    'LADERA': 'LADERA',
    'WINDSOR HILLS': 'WINDSOR HILLS',
    'MAYWOOD/CALIFORNI': 'MAYWOOD',
    'GLENDALE & BURBANK,': 'GLENDALE & BURBANK',
    'NORTH WHITTIER': 'NORTH WHITTIER',
    'NELSON': 'NELSON',
    'CALICHE': 'CALICHE',
    'GARDENA CALIF': 'GARDENA',
    'COMMERCE,': 'COMMERCE',
    'EAST RANCHO DOMINGUEZ': 'EAST RANCHO DOMINGUEZ',
    'LOS ANGELES CAD': 'LOS ANGELES',
    'WINETKA': 'WINNETKA',
    'PLAY DEL REY': 'PLAYA DEL REY',
    'LA PALMA': 'LA PALMA',
    'WEST LOS ANGELES CALIF': 'WEST LOS ANGELES',
    'SUN VALLY': 'SUN VALLEY',
    'THOUSAND OAKS': 'THOUSAND OAKS',
    'BEVERLY HILLS CALIF': 'BEVERLY HILLS',
    'S.SAN GABRIEL': 'SAN GABRIEL',
    'WESTCHESTER': 'WESTCHESTER',
    'AVOCADO HEIGHTS': 'AVOCADO HEIGHTS',
    'SUNLAND,': 'SUNLAND',
    'NORTH SAN GABRIEL': 'NORTH SAN GABRIEL',
    'SAN GABRIE': 'SAN GABRIEL',
    'SAN BABRIEL': 'SAN GABRIEL',
    'PICO RIVER': 'PICO RIVERA',
    'WATTS': 'WATTS',
    'LEON VALLEY': 'LEON VALLEY',
    'CHATSWORTH,': 'CHATSWORTH',
    'MOUNT WILSON': 'MOUNT WILSON',
    'MT GLEASON': 'MOUNT GLEASON',
    'ANAVERDE': 'ANAVERDE',
    'ALPINE BUTTE': 'ALPINE BUTTE',
    'PEARLAND': 'PEARLAND',
    'NT GLEASON': 'MOUNT GLEASON',
    'ANTELOPE VALLEY': 'ANTELOPE VALLEY',
    'WHITE FENCE FARM': 'WHITE FENCE FARM',
    'WHITE FENCE FARMS': 'WHITE FENCE FARMS',
    'QUARTZ HILL CI': 'QUARTZ HILL',
    'DELSUR': 'DEL SUR',
    'RDEMAN': 'REDMAN',
    'ANTELOPE': 'ANTELOPE',
    'ALPINEBUTTE': 'ALPINE BUTTE',
    'VILLAGE': 'VILLAGE',
    'GREN VALLEY': 'GREEN VALLEY',
    'ROOSEVELTY': 'ROOSEVELT',
    'ANTELPE ACRES': 'ANTELOPE ACRES',
    'ALPINE': 'ALPINE',
    'HUGHES LAKE': 'HUGHES LAKE',
    'ANA VERDE': 'ANA VERDE',
    'GREEN VALLE': 'GREEN VALLEY',
    'BLACK BUTT': 'BLACK BUTTE',
    'BALCK BUTTE': 'BLACK BUTTE',
    'VACANT': 'VACANT'
    
}

# %%
# Apply the dict
sales_df['City'] = sales_df['property_city'].map(lambda x: city_standardization.get(x, x))

# %%
sales_df.head()

# %%
sales_df['City'].unique().tolist()

# %%
sales_df['property_city'].unique()

# %%
# Get correct county
sales_df['County'] = sales_df['City'].apply(lambda x: city_to_la_metro_county[x])
sales_df.head()

# %%
sales_df['County'].unique()

# %%
la_metro_counties = ['Los Angeles','Riverside', 'San Bernardino', 'Orange',
       'Ventura']

# Assuming your original DataFrame is named df and has a column named 'county'
filtered_df = sales_df[sales_df['County'].isin(la_metro_counties)]

# Display the filtered DataFrame
filtered_df

# %%
filtered_df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'state', 'property_city', 'property_county', 'source_url'], inplace=True)

# %%
filtered_df.head()

# %%
filtered_df['property_type'].unique().tolist()

# %%
# Example list of counties
prop_type = ['TRIPLEX', 'INSTITUTIONAL', 'MULTI-FAMILY RESIDENCE', 'SINGLE FAMILY RESIDENCE', 'CONDOMINIUM' ,'SINGLE FAMILY DWELLING', 'CONDO OR PUD']

# Assuming your original DataFrame is named df and has a column named 'county'
final_df = filtered_df[filtered_df['property_type'].isin(prop_type)]
print(len(final_df))
# Display the filtered DataFrame
final_df.head()

# %%
def replace_abr(address):
    
    address_abbreviations = {
    "AVENUE": "AVE",
    "BOULEVARD": "BLVD",
    "COURT": "CT",
    "CIRCLE": "CIR",
    "DRIVE": "DR",
    "LANE": "LN",
    "ROAD": "RD",
    "STREET": "ST",
    "SQUARE": "SQ",
    "TERRACE": "TER",
    "WAY": "WY",
    "PLACE": "PL",
    "ALLEY": "ALY",
    "PATH": "PTH",
    "PARKWAY": "PKWY",
    "VIA": "VIA",
    "PLAZA": "PLZ",
    "HILL": "HL",
    "CRESCENT": "CRES",
    "RANCH": "RCH",
    "SOUTH": "S",
    "NORTH": "N",
    "EAST": "E",
    "WEST": "W",
    "SOUTHWEST": "SW",
    "NORTHEAST": "NE",
    "SOUTHEAST": "SE",
    "NORTHWEST": "NW"
    }
    
    ending = address.split(' ')[-1]
    
    if ending in address_abbreviations:
        
        new_end = address_abbreviations[ending]
        
        parts = address.split(' ')[:-1]
        
        new_address = parts[0]
        
        for part in parts[1:]:
            
            new_address += f' {part}'
        
        address = f'{new_address} {new_end}'
        
        return address
        
    else:
        
        return address

# %%
final_df['Address'] = final_df['property_street_address'].apply(replace_abr)

# %%
final_df =final_df.loc[final_df['property_zip5'].notna()]

# %%
final_df['zip_code'] = final_df['property_zip5'].astype(int)

# %%
final_df.head()

# %%
# obtain final address used for extracting lat and long

final_df['Address_Google'] = final_df.apply(lambda x: f'{x["Address"]}, {x["City"]}, CA {x["zip_code"]}, USA', axis=1)

# %%
final_df.head()

# %%
addresses = final_df['Address_Google'].tolist()

addresses[:5]

# %%
final_df.drop(columns=['property_zip5', 'property_street_address'], inplace=True)

# %%
final_df.to_csv('final_df.csv')

# %%
final_df.head()

# %%
# filter for type of property
prop_type = ['MULTI-FAMILY RESIDENCE', 'SINGLE FAMILY RESIDENCE','SINGLE FAMILY DWELLING']

# Assuming your original DataFrame is named df and has a column named 'county'
final_df = final_df[final_df['property_type'].isin(prop_type)]
print(len(test_df))

# %%
final_df.to_csv('final_df.csv', index=False)
